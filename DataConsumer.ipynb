# %%
# Import required packages
import pandas as pd
from kafka import KafkaProducer
import json
import os
import csv
import time

# %%
# This method archives the file after processing
def archive_file(directory,filename):
    try:
        new_filename = os.path.splitext(filename)[0] + '.txt'
        os.rename(os.path.join(directory, filename), os.path.join(directory, new_filename))
        print(f'{os.path.join(directory, filename)} ARCHIVE SUCCESSFUL')
    except:
        print('Error in archiving file')

# %%
# Name of the topic
topic= 'flight-topic'

# This method posts messages into Kafka topic
def send_kafka_topic(csv):
    try:
        # Create a Kafka producer instance
        producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                            value_serializer=lambda x: json.dumps(x).encode('utf-8'))
        # Iterate over each row of the DataFrame and send it to the Kafka topic
        for _, row in csv.iterrows():
            producer.send(topic, value=row.to_dict())

        # Close the Kafka producer
        producer.close()
        csv = None
        print(F'Write to Kafka topic {topic} completed')
        return True
    except:
        return False

# %%
# Read CSV file 
def read_csv_file(directory,csv_file):
    try:
        file_path = os.path.join(directory, csv_file)
        print('File path: ', file_path)
        chunks = pd.read_csv(file_path, chunksize=5000)
        csv = pd.concat(chunks)
        print(csv.head(2))
        res = send_kafka_topic(csv)
        if(res):
            archive_file(directory,csv_file)
        else:
            return 'FAILED during Kafka Load'
        return 'COMPLETED', len(csv)
    except:
        return 'FAILED'

# %%
# Path to directory
directory = '../FileGateway/'

retry = 0
# Wait time
n = 20

# Check for input files from the directory. Sleep after processing and RETRY the steps.
while True:
    # Check for CSV files in directory
    csv_files = [f for f in os.listdir(directory) if f.endswith('.csv')]
    if csv_files:
        # Read each CSV file
        for csv_file in csv_files:
            # with open(os.path.join(directory, csv_file)) as file:
            val, num = read_csv_file(directory,csv_file)
            print(f'File {csv_file} read status : {val}. Number of Entries {num}')
            retry=0
    else:
        print(f"No CSV files found in directory {directory}. Retrying after {n} sec")
    print("-"*65)
    # Wait n seconds before checking again
    time.sleep(n)  
    retry+=1
    # check for retry count
    if(retry==10):
        print('Job run Completed')
        break
# Out:
# No CSV files found in directory ../FileGateway/. Retrying after 20 sec
# -----------------------------------------------------------------
# No CSV files found in directory ../FileGateway/. Retrying after 20 sec
# -----------------------------------------------------------------
# File path:  ../FileGateway/2009.csv
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2009-01-01         XE               1204    DCA  EWR          1100
# 1  2009-01-01         XE               1206    EWR  IAD          1510
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0    1058.0       -2.0      18.0      1116.0  ...              62.0
# 1    1509.0       -1.0      28.0      1537.0  ...              82.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# 0                 68.0      42.0     199.0            NaN            NaN
# 1                 75.0      43.0     213.0            NaN            NaN
#
#   NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 27
# 0       NaN             NaN                  NaN          NaN
# 1       NaN             NaN                  NaN          NaN
#
# [2 rows x 28 columns]
# Write to Kafka topic flight-topic completed
# ../FileGateway/2009.csv ARCHIVE SUCCESSFUL
# File 2009.csv read status : COMPLETED. Number of Entries 6429338
# File path:  ../FileGateway/2010.csv
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2010-01-01         MQ               4438    LGA  RDU          1940
# 1  2010-01-01         MQ               4440    DCA  JFK           950
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0    2101.0       81.0      14.0      2115.0  ...             110.0
# 1     949.0       -1.0      13.0      1002.0  ...              70.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# 0                106.0      70.0     431.0            0.0            0.0
# 1                 60.0      38.0     213.0            NaN            NaN
#
#   NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 27
# 0       0.0             0.0                 77.0          NaN
# 1       NaN             NaN                  NaN          NaN
#
# [2 rows x 28 columns]
# Write to Kafka topic flight-topic completed
# ../FileGateway/2010.csv ARCHIVE SUCCESSFUL
# File 2010.csv read status : COMPLETED. Number of Entries 6450117
# File path:  ../FileGateway/2011.csv
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2011-01-01         MQ               4529    BOS  JFK          1830
# 1  2011-01-01         MQ               4532    BNA  DCA          1100
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0    1823.0       -7.0      68.0      1931.0  ...              90.0
# 1    1052.0       -8.0      11.0      1103.0  ...              95.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# 0                146.0      48.0     187.0            0.0            0.0
# 1                 88.0      74.0     562.0            NaN            NaN
#
#   NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 27
# 0      49.0             0.0                  0.0          NaN
# 1       NaN             NaN                  NaN          NaN
#
# [2 rows x 28 columns]
# Write to Kafka topic flight-topic completed
# ../FileGateway/2011.csv ARCHIVE SUCCESSFUL
# File 2011.csv read status : COMPLETED. Number of Entries 6066650
# -----------------------------------------------------------------
# File path:  ../FileGateway/2018.csv
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2018-01-01         UA               2429    EWR  DEN          1517
# 1  2018-01-01         UA               2427    LAS  SFO          1115
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0    1512.0       -5.0      15.0      1527.0  ...             268.0
# 1    1107.0       -8.0      11.0      1118.0  ...              99.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# 0                250.0     225.0    1605.0            NaN            NaN
# 1                 83.0      65.0     414.0            NaN            NaN
#
#   NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 27
# 0       NaN             NaN                  NaN          NaN
# 1       NaN             NaN                  NaN          NaN
#
# [2 rows x 28 columns]
# Write to Kafka topic flight-topic completed
# ../FileGateway/2018.csv ARCHIVE SUCCESSFUL
# File 2018.csv read status : COMPLETED. Number of Entries 7213446
# File path:  ../FileGateway/2015.csv
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2015-01-01         NK                195    MCO  FLL          2147
# 1  2015-01-01         NK                197    LGA  FLL          1050
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0    2143.0       -4.0      15.0      2158.0  ...              63.0
# 1    1104.0       14.0      20.0      1124.0  ...             194.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# 0                 62.0      40.0     177.0            NaN            NaN
# 1                179.0     150.0    1076.0            NaN            NaN
#
#   NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 27
# 0       NaN             NaN                  NaN          NaN
# 1       NaN             NaN                  NaN          NaN
#
# [2 rows x 28 columns]
# Write to Kafka topic flight-topic completed
# ../FileGateway/2015.csv ARCHIVE SUCCESSFUL
# File 2015.csv read status : COMPLETED. Number of Entries 5819079
# File path:  ../FileGateway/2014.csv
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2014-01-01         AA               2377    ICT  DFW          1135
# 1  2014-01-01         AA               2378    MIA  TPA          2225
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0    1144.0        9.0      12.0      1156.0  ...              85.0
# 1    2220.0       -5.0      14.0      2234.0  ...              60.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# 0                 78.0      57.0     328.0            NaN            NaN
# 1                 55.0      37.0     204.0            NaN            NaN
#
#   NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 27
# 0       NaN             NaN                  NaN          NaN
# 1       NaN             NaN                  NaN          NaN
#
# [2 rows x 28 columns]
# Write to Kafka topic flight-topic completed
# ../FileGateway/2014.csv ARCHIVE SUCCESSFUL
# File 2014.csv read status : COMPLETED. Number of Entries 5819811
# File path:  ../FileGateway/2016.csv
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2016-01-01         DL               1248    DTW  LAX          1935
# 1  2016-01-01         DL               1251    ATL  GRR          2125
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0    1935.0        0.0      23.0      1958.0  ...             309.0
# 1    2130.0        5.0      13.0      2143.0  ...             116.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# 0                285.0     249.0    1979.0            NaN            NaN
# 1                109.0      92.0     640.0            NaN            NaN
#
#   NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 27
# 0       NaN             NaN                  NaN          NaN
# 1       NaN             NaN                  NaN          NaN
#
# [2 rows x 28 columns]
# Write to Kafka topic flight-topic completed
# ../FileGateway/2016.csv ARCHIVE SUCCESSFUL
# File 2016.csv read status : COMPLETED. Number of Entries 5617658
# File path:  ../FileGateway/2017.csv
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2017-01-01         AA                  1    JFK  LAX           800
# 1  2017-01-01         AA                  2    LAX  JFK           900
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0     831.0       31.0      25.0       856.0  ...             402.0
# 1     934.0       34.0      34.0      1008.0  ...             327.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# 0                398.0     347.0    2475.0           27.0            0.0
# 1                335.0     289.0    2475.0           34.0            0.0
#
#   NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 27
# 0       0.0             0.0                  0.0          NaN
# 1       8.0             0.0                  0.0          NaN
#
# [2 rows x 28 columns]
# Write to Kafka topic flight-topic completed
# ../FileGateway/2017.csv ARCHIVE SUCCESSFUL
# File 2017.csv read status : COMPLETED. Number of Entries 5674621
# File path:  ../FileGateway/2013.csv
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2013-01-01         VX                108    LAX  IAD           700
# 1  2013-01-01         VX                114    LAX  IAD          2205
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0     700.0        0.0       8.0       708.0  ...             285.0
# 1    2204.0       -1.0      12.0      2216.0  ...             280.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# 0                258.0     243.0    2288.0            NaN            NaN
# 1                272.0     247.0    2288.0            NaN            NaN
#
#   NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 27
# 0       NaN             NaN                  NaN          NaN
# 1       NaN             NaN                  NaN          NaN
#
# [2 rows x 28 columns]
# Write to Kafka topic flight-topic completed
# ../FileGateway/2013.csv ARCHIVE SUCCESSFUL
# File 2013.csv read status : COMPLETED. Number of Entries 6369482
# File path:  ../FileGateway/2012.csv
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2012-01-01         MQ               4041    BMI  ORD        1715.0
# 1  2012-01-01         MQ               4041    ORD  BMI        1545.0
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0    1702.0      -13.0       9.0      1711.0  ...              55.0
# 1    1540.0       -5.0      11.0      1551.0  ...              50.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# 0                 55.0      37.0     116.0            NaN            NaN
# 1                 39.0      23.0     116.0            NaN            NaN
#
#   NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 27
# 0       NaN             NaN                  NaN          NaN
# 1       NaN             NaN                  NaN          NaN
#
# [2 rows x 28 columns]
# Write to Kafka topic flight-topic completed
# ../FileGateway/2012.csv ARCHIVE SUCCESSFUL
# File 2012.csv read status : COMPLETED. Number of Entries 6096762
# -----------------------------------------------------------------
# No CSV files found in directory ../FileGateway/. Retrying after 20 sec
# -----------------------------------------------------------------
# No CSV files found in directory ../FileGateway/. Retrying after 20 sec
# -----------------------------------------------------------------
# No CSV files found in directory ../FileGateway/. Retrying after 20 sec
# -----------------------------------------------------------------
# No CSV files found in directory ../FileGateway/. Retrying after 20 sec
# -----------------------------------------------------------------
# Job run Completed
